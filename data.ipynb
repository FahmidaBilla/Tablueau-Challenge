# %%
import pandas as pd
import numpy as np
import glob

# %%
# list all csv files only
csv_files = glob.glob('Resources/JC-*.csv')
csv_files
# Out:
# ['Resources/JC-202209-citibike-tripdata.csv',
#  'Resources/JC-202207-citbike-tripdata.csv',
#  'Resources/JC-202205-citibike-tripdata.csv',
#  'Resources/JC-202208-citibike-tripdata.csv',
#  'Resources/JC-202206-citibike-tripdata.csv']

# %%
combined_citibike_csv = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
combined_citibike_csv
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       4999883C92EACCB0   classic_bike  2022-09-01 21:05:47
# 1       CC87E6815E075F6F   classic_bike  2022-09-10 18:09:26
# 2       B54E7FDDF4C251E6   classic_bike  2022-09-26 21:46:24
# 3       A19A3DC77A98F6C2   classic_bike  2022-09-08 20:11:41
# 4       3530E340A0B0E93F   classic_bike  2022-09-08 17:05:38
# ...                  ...            ...                  ...
# 511756  25AD34565A260732   classic_bike  2022-06-17 16:03:36
# 511757  8A4181FCE9439036   classic_bike  2022-06-25 14:14:26
# 511758  28C8501BCB596743  electric_bike  2022-06-04 08:57:04
# 511759  D28575BBFF3A0B57   classic_bike  2022-06-17 06:11:05
# 511760  A914FEF9390C201C  electric_bike  2022-06-02 18:15:17
#
#                    ended_at                            start_station_name  \
# 0       2022-09-01 21:08:07                                  Jersey & 3rd
# 1       2022-09-10 18:11:48                                  Jersey & 3rd
# ...

# %%
combined_citibike_csv.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
combined_citibike_csv["started_at"] = pd.to_datetime(combined_citibike_csv["started_at"])
combined_citibike_csv["ended_at"] = pd.to_datetime(combined_citibike_csv["ended_at"])

combined_citibike_csv.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
combined_citibike_csv = combined_citibike_csv.sort_values("started_at")

combined_citibike_csv.head()
# Out:
#                  ride_id  rideable_type          started_at  \
# 267840  E0888D1157FDBE22   classic_bike 2022-05-01 00:01:29
# 224784  BC0481A24404E4A6  electric_bike 2022-05-01 00:03:39
# 224403  E47ADF195554DD3E   classic_bike 2022-05-01 00:04:10
# 237836  F7AA5C52904F6DDF  electric_bike 2022-05-01 00:04:29
# 268789  8DDD0552D490C5E3   classic_bike 2022-05-01 00:04:41
#
#                   ended_at          start_station_name start_station_id  \
# 267840 2022-05-01 00:06:52  Columbus Dr at Exchange Pl            JC106
# 224784 2022-05-01 00:18:45           JC Medical Center            JC011
# 224403 2022-05-01 00:18:44           JC Medical Center            JC011
# 237836 2022-05-01 00:08:05        8 St & Washington St            HB603
# 268789 2022-05-01 00:08:06               Grove St PATH            JC005
#
#          end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 267840       Morris Canal          JC072  40.716870 -74.032810  40.712419
# ...

# %%
#break out month
combined_citibike_csv['Trip Month'] = combined_citibike_csv["started_at"].dt.month_name()
combined_citibike_csv.head()
# Out:
#                  ride_id  rideable_type          started_at  \
# 267840  E0888D1157FDBE22   classic_bike 2022-05-01 00:01:29
# 224784  BC0481A24404E4A6  electric_bike 2022-05-01 00:03:39
# 224403  E47ADF195554DD3E   classic_bike 2022-05-01 00:04:10
# 237836  F7AA5C52904F6DDF  electric_bike 2022-05-01 00:04:29
# 268789  8DDD0552D490C5E3   classic_bike 2022-05-01 00:04:41
#
#                   ended_at          start_station_name start_station_id  \
# 267840 2022-05-01 00:06:52  Columbus Dr at Exchange Pl            JC106
# 224784 2022-05-01 00:18:45           JC Medical Center            JC011
# 224403 2022-05-01 00:18:44           JC Medical Center            JC011
# 237836 2022-05-01 00:08:05        8 St & Washington St            HB603
# 268789 2022-05-01 00:08:06               Grove St PATH            JC005
#
#          end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 267840       Morris Canal          JC072  40.716870 -74.032810  40.712419
# ...

# %%
combined_citibike_csv.value_counts("member_casual")
# Out:
# member_casual
# member    318360
# casual    193401
# dtype: int64

# %%
combined_citibike_csv.value_counts("Trip Month")
# Out:
# Trip Month
# August       115231
# July         108502
# September    104247
# June         103299
# May           80482
# dtype: int64

# %%
# Export the DataFrame as a CSV file. 
combined_citibike_csv.to_csv("Resources/combined_citibike.csv", encoding='utf8', index=False)
